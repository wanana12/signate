# %% [markdown]
# <a href="https://colab.research.google.com/github/wanana12/signate/blob/main/wine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## ライブラリの読み込み

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## データの読み込み

# %%
# !ls /content/drive/MyDrive/wine
# Out:
# sample_submit.csv  test.tsv  train.tsv

# %%
train = pd.read_csv("/content/drive/MyDrive/wine/train.tsv", sep='\t')
test = pd.read_csv("/content/drive/MyDrive/wine/test.tsv", sep='\t')
sample_submit = pd.read_csv("/content/drive/MyDrive/wine/sample_submit.csv", header=None)

# %%
sample_submit.head()
# Out:
#    0  1
# 0  2  3
# 1  4  3
# 2  5  3
# 3  7  1
# 4  8  3

# %%
train.head()
# Out:
#    id  Y  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0   0  3    12.36        3.83  2.38               21.0         88
# 1   1  2    12.42        4.43  2.73               26.5        102
# 2   3  1    13.05        1.77  2.10               17.0        107
# 3   6  1    13.05        1.65  2.55               18.0         98
# 4   9  1    13.05        2.05  3.22               25.0        124
#
#    Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0           2.30        0.92                  0.50             1.04
# 1           2.20        2.13                  0.43             1.71
# 2           3.00        3.00                  0.28             2.03
# 3           2.45        2.43                  0.29             1.44
# 4           2.63        2.68                  0.47             1.92
#
#    Color intensity   Hue  OD280/OD315 of diluted wines  Proline
# 0             7.65  0.56                          1.58      520
# ...

# %%
test.head()
# Out:
#    id  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  Total phenols  \
# 0   2    14.10        2.16  2.30               18.0        105           2.95
# 1   4    13.23        3.30  2.28               18.5         98           1.80
# 2   5    12.08        1.13  2.51               24.0         78           2.00
# 3   7    12.08        1.83  2.32               18.5         81           1.60
# 4   8    14.30        1.92  2.72               20.0        120           2.80
#
#    Flavanoids  Nonflavanoid phenols  Proanthocyanins  Color intensity   Hue  \
# 0        3.32                  0.22             2.38             5.75  1.25
# 1        0.83                  0.61             1.87            10.52  0.56
# 2        1.58                  0.40             1.40             2.20  1.31
# 3        1.50                  0.52             1.64             2.40  1.08
# 4        3.14                  0.33             1.97             6.20  1.07
#
# ...

# %% [markdown]
# ## pandasプロット

# %%
sns.countplot(x="Y", data=train)
plt.show()

# %% [markdown]
# ## データ前処理

# %%
data = pd.concat([train, test], sort=False)

# %%
data.head()
# Out:
#    id    Y  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0   0  3.0    12.36        3.83  2.38               21.0         88
# 1   1  2.0    12.42        4.43  2.73               26.5        102
# 2   3  1.0    13.05        1.77  2.10               17.0        107
# 3   6  1.0    13.05        1.65  2.55               18.0         98
# 4   9  1.0    13.05        2.05  3.22               25.0        124
#
#    Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0           2.30        0.92                  0.50             1.04
# 1           2.20        2.13                  0.43             1.71
# 2           3.00        3.00                  0.28             2.03
# 3           2.45        2.43                  0.29             1.44
# 4           2.63        2.68                  0.47             1.92
#
#    Color intensity   Hue  OD280/OD315 of diluted wines  Proline
# 0             7.65  0.56                          1.58      520
# ...

# %%
print(len(train), len(test), len(data))
# Out:
# 89 89 178

# %%
data.isnull().sum()
# Out:
# id                               0
# Y                               89
# Alcohol                          0
# Malic acid                       0
# Ash                              0
# Alcalinity of ash                0
# Magnesium                        0
# Total phenols                    0
# Flavanoids                       0
# Nonflavanoid phenols             0
# Proanthocyanins                  0
# Color intensity                  0
# Hue                              0
# OD280/OD315 of diluted wines     0
# Proline                          0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 178 entries, 0 to 88
# Data columns (total 15 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            178 non-null    int64
#  1   Y                             89 non-null     float64
#  2   Alcohol                       178 non-null    float64
#  3   Malic acid                    178 non-null    float64
#  4   Ash                           178 non-null    float64
#  5   Alcalinity of ash             178 non-null    float64
#  6   Magnesium                     178 non-null    int64
#  7   Total phenols                 178 non-null    float64
#  8   Flavanoids                    178 non-null    float64
#  9   Nonflavanoid phenols          178 non-null    float64
#  10  Proanthocyanins               178 non-null    float64
#  11  Color intensity               178 non-null    float64
# ...

# %%
delete_columns = ['id']
data.drop(delete_columns, axis=1, inplace=True)
data.head()
# Out:
#      Y  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0  3.0    12.36        3.83  2.38               21.0         88
# 1  2.0    12.42        4.43  2.73               26.5        102
# 2  1.0    13.05        1.77  2.10               17.0        107
# 3  1.0    13.05        1.65  2.55               18.0         98
# 4  1.0    13.05        2.05  3.22               25.0        124
#
#    Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0           2.30        0.92                  0.50             1.04
# 1           2.20        2.13                  0.43             1.71
# 2           3.00        3.00                  0.28             2.03
# 3           2.45        2.43                  0.29             1.44
# 4           2.63        2.68                  0.47             1.92
#
#    Color intensity   Hue  OD280/OD315 of diluted wines  Proline
# 0             7.65  0.56                          1.58      520
# ...

# %%
train = data[:len(train)]
test = data[len(train):]

# %%
y_train = train['Y']
X_train = train.drop('Y', axis = 1)
X_test = test.drop('Y', axis = 1)

# %%
X_train.head()
# Out:
#    Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  Total phenols  \
# 0    12.36        3.83  2.38               21.0         88           2.30
# 1    12.42        4.43  2.73               26.5        102           2.20
# 2    13.05        1.77  2.10               17.0        107           3.00
# 3    13.05        1.65  2.55               18.0         98           2.45
# 4    13.05        2.05  3.22               25.0        124           2.63
#
#    Flavanoids  Nonflavanoid phenols  Proanthocyanins  Color intensity   Hue  \
# 0        0.92                  0.50             1.04             7.65  0.56
# 1        2.13                  0.43             1.71             2.08  0.92
# 2        3.00                  0.28             2.03             5.04  0.88
# 3        2.43                  0.29             1.44             4.25  1.12
# 4        2.68                  0.47             1.92             3.58  1.13
#
#    OD280/OD315 of diluted wines  Proline
# ...

# %%
y_train.head()
# Out:
# 0    3.0
# 1    2.0
# 2    1.0
# 3    1.0
# 4    1.0
# Name: Y, dtype: float64

# %% [markdown]
# ## 機械学習

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
clf = RandomForestClassifier()

# %%
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = clf.predict(X_test)

# %%
y_pred[:20]
# Out:
# array([1., 3., 2., 2., 1., 1., 2., 2., 1., 2., 1., 3., 1., 2., 3., 1., 3.,
#        1., 3., 2.])

# %%
clf.score(X_train, y_train)
# Out:
# 1.0

# %% [markdown]
# ## データの出力

# %%
sub = sample_submit
sub[1] = list(map(int, y_pred))
sub.to_csv("/content/drive/MyDrive/wine/submit.csv", index=False, header=False)

# %%
sub.head()
# Out:
#    0  1
# 0  2  1
# 1  4  3
# 2  5  2
# 3  7  2
# 4  8  1
