# %% [markdown]
# ## ライブラリの読み込み

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## データの読み込み

# %%
# !ls /content/drive/MyDrive/mushroom
# Out:
# sample_submit.csv  submit.csv  test.tsv  train.tsv

# %%
train = pd.read_csv("/content/drive/MyDrive/mushroom/train.tsv", sep='\t')
test = pd.read_csv("/content/drive/MyDrive/mushroom/test.tsv", sep='\t')
sample_submit = pd.read_csv("/content/drive/MyDrive/mushroom/sample_submit.csv", header=None)

# %%
sample_submit.head()
# Out:
#    0  1
# 0  1  e
# 1  4  e
# 2  6  e
# 3  8  p
# 4  9  e

# %%
train.head()
# Out:
#    id  Y cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0   0  p         f           y         n       f    f               f
# 1   2  p         f           y         y       f    f               f
# 2   3  e         b           y         w       t    l               f
# 3   5  p         x           s         b       t    f               f
# 4   7  p         x           s         w       t    f               f
#
#   gill-spacing gill-size  ... stalk-surface-below-ring stalk-color-above-ring  \
# 0            c         n  ...                        k                      w
# 1            c         b  ...                        k                      b
# 2            c         b  ...                        s                      w
# 3            c         b  ...                        s                      w
# 4            c         b  ...                        f                      w
#
#   stalk-color-below-ring veil-type veil-color ring-number ring-type  \
# 0                      w         p          w           o         e
# 1                      p         p          w           o         l
# 2                      w         p          w           o         p
# 3                      w         p          w           o         p
# 4                      w         p          w           o         p
#
#   spore-print-color population habitat
# 0                 w          v       d
# 1                 h          y       g
# 2                 k          n       m
# 3                 h          v       u
# 4                 h          v       g
#
# [5 rows x 24 columns]

# %%
test.head()
# Out:
#    id cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0   1         x           s         w       t    f               f
# 1   4         f           y         g       t    n               f
# 2   6         x           y         e       t    n               f
# 3   8         f           s         g       t    f               f
# 4   9         x           s         e       f    y               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         b          p  ...                        f
# 1            c         b          n  ...                        s
# 2            c         b          w  ...                        s
# 3            c         b          p  ...                        s
# 4            c         n          b  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# 1                      p                      g         p          w
# 2                      w                      p         p          w
# 3                      w                      w         p          w
# 4                      w                      w         p          w
#
#   ring-number ring-type spore-print-color population habitat
# 0           o         p                 h          v       g
# 1           o         p                 n          y       d
# 2           o         p                 n          y       d
# 3           o         p                 h          v       g
# 4           o         e                 w          v       l
#
# [5 rows x 23 columns]

# %% [markdown]
# ## pandasプロット

# %%
sns.countplot(x="Y", data=train)
plt.show()

# %% [markdown]
# ## データ前処理

# %%
data = pd.concat([train, test], sort=False)

# %%
data.head()
# Out:
#    id  Y cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0   0  p         f           y         n       f    f               f
# 1   2  p         f           y         y       f    f               f
# 2   3  e         b           y         w       t    l               f
# 3   5  p         x           s         b       t    f               f
# 4   7  p         x           s         w       t    f               f
#
#   gill-spacing gill-size  ... stalk-surface-below-ring stalk-color-above-ring  \
# 0            c         n  ...                        k                      w
# 1            c         b  ...                        k                      b
# 2            c         b  ...                        s                      w
# 3            c         b  ...                        s                      w
# 4            c         b  ...                        f                      w
#
#   stalk-color-below-ring veil-type veil-color ring-number ring-type  \
# 0                      w         p          w           o         e
# 1                      p         p          w           o         l
# 2                      w         p          w           o         p
# 3                      w         p          w           o         p
# 4                      w         p          w           o         p
#
#   spore-print-color population habitat
# 0                 w          v       d
# 1                 h          y       g
# 2                 k          n       m
# 3                 h          v       u
# 4                 h          v       g
#
# [5 rows x 24 columns]

# %%
print(len(train), len(test), len(data))
# Out:
# 4062 4062 8124

# %%
data.isnull().sum()
# Out:
# id                             0
# Y                           4062
# cap-shape                      0
# cap-surface                    0
# cap-color                      0
# bruises                        0
# odor                           0
# gill-attachment                0
# gill-spacing                   0
# gill-size                      0
# gill-color                     0
# stalk-shape                    0
# stalk-root                     0
# stalk-surface-above-ring       0
# stalk-surface-below-ring       0
# stalk-color-above-ring         0
# stalk-color-below-ring         0
# veil-type                      0
# veil-color                     0
# ring-number                    0
# ring-type                      0
# spore-print-color              0
# population                     0
# habitat                        0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8124 entries, 0 to 4061
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        8124 non-null   int64
#  1   Y                         4062 non-null   object
#  2   cap-shape                 8124 non-null   object
#  3   cap-surface               8124 non-null   object
#  4   cap-color                 8124 non-null   object
#  5   bruises                   8124 non-null   object
#  6   odor                      8124 non-null   object
#  7   gill-attachment           8124 non-null   object
#  8   gill-spacing              8124 non-null   object
#  9   gill-size                 8124 non-null   object
#  10  gill-color                8124 non-null   object
#  11  stalk-shape               8124 non-null   object
#  12  stalk-root                8124 non-null   object
#  13  stalk-surface-above-ring  8124 non-null   object
#  14  stalk-surface-below-ring  8124 non-null   object
#  15  stalk-color-above-ring    8124 non-null   object
#  16  stalk-color-below-ring    8124 non-null   object
#  17  veil-type                 8124 non-null   object
#  18  veil-color                8124 non-null   object
#  19  ring-number               8124 non-null   object
#  20  ring-type                 8124 non-null   object
#  21  spore-print-color         8124 non-null   object
#  22  population                8124 non-null   object
#  23  habitat                   8124 non-null   object
# dtypes: int64(1), object(23)
# memory usage: 1.5+ MB

# %% [markdown]
# ## ラベルエンコーディング

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

data['cap-shape'] = le.fit_transform(data['cap-shape'])
data['cap-surface'] = le.fit_transform(data['cap-surface'])
data['cap-color'] = le.fit_transform(data['cap-color'])
data['bruises'] = le.fit_transform(data['bruises'])
data['odor'] = le.fit_transform(data['odor'])
data['gill-attachment'] = le.fit_transform(data['gill-attachment'])
data['gill-spacing'] = le.fit_transform(data['gill-spacing'])
data['gill-size'] = le.fit_transform(data['gill-size'])
data['gill-color'] = le.fit_transform(data['gill-color'])
data['stalk-shape'] = le.fit_transform(data['stalk-shape'])
data['stalk-root'] = le.fit_transform(data['stalk-root'])
data['stalk-surface-above-ring'] = le.fit_transform(data['stalk-surface-above-ring'])
data['stalk-surface-below-ring'] = le.fit_transform(data['stalk-surface-below-ring'])
data['stalk-color-above-ring'] = le.fit_transform(data['stalk-color-above-ring'])
data['stalk-color-below-ring'] = le.fit_transform(data['stalk-color-below-ring'])
data['veil-type'] = le.fit_transform(data['veil-type'])
data['veil-color'] = le.fit_transform(data['veil-color'])
data['ring-number'] = le.fit_transform(data['ring-number'])
data['ring-type'] = le.fit_transform(data['ring-type'])
data['spore-print-color'] = le.fit_transform(data['spore-print-color'])
data['population'] = le.fit_transform(data['population'])
data['habitat'] = le.fit_transform(data['habitat'])

data.head()
# Out:
#    id  Y  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0   0  p          2            3          4        0     2                1
# 1   2  p          2            3          9        0     2                1
# 2   3  e          0            3          8        1     3                1
# 3   5  p          5            2          0        1     2                1
# 4   7  p          5            2          8        1     2                1
#
#    gill-spacing  gill-size  ...  stalk-surface-below-ring  \
# 0             0          1  ...                         1
# 1             0          0  ...                         1
# 2             0          0  ...                         2
# 3             0          0  ...                         2
# 4             0          0  ...                         0
#
#    stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# 0                       7                       7          0           2
# 1                       0                       6          0           2
# 2                       7                       7          0           2
# 3                       7                       7          0           2
# 4                       7                       7          0           2
#
#    ring-number  ring-type  spore-print-color  population  habitat
# 0            1          0                  7           4        0
# 1            1          2                  1           5        1
# 2            1          4                  2           2        3
# 3            1          4                  1           4        5
# 4            1          4                  1           4        1
#
# [5 rows x 24 columns]

# %%
delete_columns = ['id']
data.drop(delete_columns, axis=1, inplace=True)
data.head()
# Out:
#    Y  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0  p          2            3          4        0     2                1
# 1  p          2            3          9        0     2                1
# 2  e          0            3          8        1     3                1
# 3  p          5            2          0        1     2                1
# 4  p          5            2          8        1     2                1
#
#    gill-spacing  gill-size  gill-color  ...  stalk-surface-below-ring  \
# 0             0          1           0  ...                         1
# 1             0          0           7  ...                         1
# 2             0          0           4  ...                         2
# 3             0          0           3  ...                         2
# 4             0          0          10  ...                         0
#
#    stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# 0                       7                       7          0           2
# 1                       0                       6          0           2
# 2                       7                       7          0           2
# 3                       7                       7          0           2
# 4                       7                       7          0           2
#
#    ring-number  ring-type  spore-print-color  population  habitat
# 0            1          0                  7           4        0
# 1            1          2                  1           5        1
# 2            1          4                  2           2        3
# 3            1          4                  1           4        5
# 4            1          4                  1           4        1
#
# [5 rows x 23 columns]

# %%
train = data[:len(train)]
test = data[len(train):]

# %%
y_train = train['Y']
X_train = train.drop('Y', axis = 1)
X_test = test.drop('Y', axis = 1)

# %%
X_train.head()
# Out:
#    cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0          2            3          4        0     2                1
# 1          2            3          9        0     2                1
# 2          0            3          8        1     3                1
# 3          5            2          0        1     2                1
# 4          5            2          8        1     2                1
#
#    gill-spacing  gill-size  gill-color  stalk-shape  ...  \
# 0             0          1           0            1  ...
# 1             0          0           7            0  ...
# 2             0          0           4            0  ...
# 3             0          0           3            1  ...
# 4             0          0          10            1  ...
#
#    stalk-surface-below-ring  stalk-color-above-ring  stalk-color-below-ring  \
# 0                         1                       7                       7
# 1                         1                       0                       6
# 2                         2                       7                       7
# 3                         2                       7                       7
# 4                         0                       7                       7
#
#    veil-type  veil-color  ring-number  ring-type  spore-print-color  \
# 0          0           2            1          0                  7
# 1          0           2            1          2                  1
# 2          0           2            1          4                  2
# 3          0           2            1          4                  1
# 4          0           2            1          4                  1
#
#    population  habitat
# 0           4        0
# 1           5        1
# 2           2        3
# 3           4        5
# 4           4        1
#
# [5 rows x 22 columns]

# %%
y_train.head()
# Out:
# 0    p
# 1    p
# 2    e
# 3    p
# 4    p
# Name: Y, dtype: object

# %%
y_train = le.fit_transform(y_train)
print(le.classes_)
# Out:
# ['e' 'p']

# %% [markdown]
# ## 機械学習

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
clf = RandomForestClassifier()

# %%
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = clf.predict(X_test)

# %%
y_pred[:20]
# Out:
# array([1, 0, 0, 1, 1, 0, 1, 0, 0, 0, 1, 1, 0, 1, 1, 1, 0, 0, 0, 0])

# %%
clf.score(X_train, y_train)
# Out:
# 1.0

# %%
y_pred = le.inverse_transform(y_pred)
y_pred[:20]
# Out:
# array(['p', 'e', 'e', 'p', 'p', 'e', 'p', 'e', 'e', 'e', 'p', 'p', 'e',
#        'p', 'p', 'p', 'e', 'e', 'e', 'e'], dtype=object)

# %%
print(le.classes_)
# Out:
# ['e' 'p']

# %% [markdown]
# ## データの出力

# %%
sub = sample_submit
sub[1] = y_pred
sub.to_csv("/content/drive/MyDrive/mushroom/submit.csv", index=False, header=False)

# %%
sub.head()
# Out:
#    0  1
# 0  1  p
# 1  4  e
# 2  6  e
# 3  8  p
# 4  9  p
